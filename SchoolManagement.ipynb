# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Arch3r/School-Management-Simulator/blob/main/SchoolManagement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a Python-based School Management System that contains three different sections: Admin, Teacher, and Parent. The system should continuously run using loops and allow different users to perform different tasks through a menu-driven interface. The Admin section should allow the user to add new students into the system, store student details such as roll number, name, class, and parent name, and manage all student records using dictionaries. Each student should have a unique roll number, and sets should be used wherever necessary to avoid duplicate student entries or duplicate subjects. The Teacher section should allow teachers to create and update report cards for students by entering marks of different subjects. Subject names can be stored in sets while marks and grades should be managed using dictionaries. Teachers should also be able to calculate total marks, average marks, percentage, and grade for every student. The Parent section should allow parents to search for their child using roll number and view the complete report card, including subjects, marks, percentage, grades, and attendance information. Lists should be used to store attendance records, activity logs, or recent test scores. The program should include proper validations such as preventing duplicate roll numbers, checking whether a student exists before generating a report card, and handling invalid menu choices. Additionally, the system should provide features such as displaying all students, showing toppers of the class, finding failed students, calculating class averages, and displaying all unique subjects taught in the school using sets. The entire program should be modular and divided into multiple functions to make the system organized and easier to maintain.

# %% [markdown]
# The Admin section should allow the user to
# * add new students into the system,
# * store student details such as roll number, name, class, and parent name, and manage all student records using dictionaries.
# * Each student should have a unique roll number, and
# * sets should be used wherever necessary to avoid duplicate student entries or duplicate subjects.

# %%
students={
    "student1":{
        "name":"Sarah Jones",
        "roll-number":"2025-526",
        "parent":"Brian Jones",
        "class":7,

    },
    "student2":{
        "name":"Zeenat Olumegbon",
        "roll-number":"2025-603",
        "parent":"Lateefat Olumegbon",
        "class":6,

    },
    "student3":{
        "name":"Kaylee Thompson",
        "roll-number":"2025-601",
        "parent":"Liana Thompson",
        "class":6,

    },
    "student4":{
        "name":"Keeley Ferraro",
        "roll-number":"2025-515",
        "parent":"Brianna Ferraro",
        "class":6,

    },
    "student5":{
        "name":"John Bell",
        "roll-number":"2026-125",
        "parent":"Jacob Bell",
        "class":8,

    },
    "student6":{
        "name":"Justin Sekyi",
        "roll-number":"2025-525",
        "parent":"Joseph Sekyi",
        "class":7,

    },
    "student7":{
        "name":"Carter Lee",
        "roll-number":"2025-125",
        "parent":"Carson Lee",
        "class":8,

    }
}

subjects={"Math","Science","E.L.A","Social Studies"}

# %%
#admin function
def add_student():

  while True:

    global name
    global number

    name=input("Enter new student full name and type 'exit' to exit: ")

    if name=='exit':
      return

    else:
     number=input("Enter student number(e.g student 1,student2 etc): ")

    if name in students.items():
      print("Student already exists")
      new_name=input("Enter new student name: ")
      students.update({number:{'name':new_name}})
      print(new_name,"has been added")

    elif number in students.items():
      print("Student number already exists")
      new_number=input("Enter student number(e.g student 1,student2 etc): ")

      students.update({new_number:{'name':name}})
      print(name,"has been added")


    else:
      students.update({number:{'name':name}})
      print(name,"has been added")


def store_data():
  while True:

    global name
    global number

    ask=input("Enter the student number you want to store data: ")
    #print(ask)

    '''print(students[ask])

    #found=""
    #for k,v in .items():
      #print(k,v)
      if ask == ask:

        print("Student Found")
        roll_num=input("Enter student roll number:  ")
        parent=input("Enter student parent name: ")
        Class=int(input("Enter student class: "))


        students[number].update({number:{'name':name,'roll number':roll_num,'parent':parent,'class':Class}})
        print("Student Information updated!")
        break
      else:
        continue
        '''
    if ask in students:
      print("Student Found")
      roll_num=input("Enter student roll number:  ")
      parent=input("Enter student parent name: ")
      ClassNum=int(input("Enter student class: "))

      students[number].update({'name':name,'roll-number':roll_num,'parent':parent,'class':ClassNum})
      print("Student Information updated!")
      return
    else:
      print("Student Not Found")


def display_all():

  for i in students.keys():
       print(i)
       print(students[i]['name'])
       print("---------------------")
  return

def admin_menu():

   while True:
    print("1.Add Student")
    print("2.Store Data")
    print("3.Display all students")
    ask=int(input("What would you like to do: "))
    if ask==1:
      add_student()
    elif ask==2:
      store_data()
    elif ask==3:
      display_all()
    elif ask==4:
      return
    else:
      print("Invalid Input")

# %%
#teacher functions
def create_reportCards():
  st_name=input("Enter student name: ")

  st_number=input("Enter student number(e.g student1, student2 etc.): ")

  if st_number in students and st_name==students[st_number]["name"]:

    math_mark=int(input("Enter the mark for Math: "))
    ela_mark=int(input("Enter the mark for E.L.A: "))
    sci_mark=int(input("Enter the mark for Science: "))
    ss_mark=int(input("Enter the mark for Social Studies: "))

    mathgrade=input("Enter the student Math grade: ")
    elagrade=input("Enter the student E.L.A grade: ")
    ssgrade=input("Enter the student Social Studies grade: ")
    scigrade=input("Enter the student Science grade: ")
    print("Report card Has been created for",st_name)
  else:
    print("Student Not In System")
    return

  students[st_number]["reportCard"] = {
    "grade": [mathgrade, elagrade, scigrade, ssgrade],
    "Math": math_mark,
    "E.L.A": ela_mark,
    "Science": sci_mark,
    "Social Studies": ss_mark
  }

def update_reportCards():
  while True:
    ask=input("What would you like to update,('sci_mark','ela_mark','math_mark','ss_mark' or 'exit'): ").lower()

    if ask=='exit':
      return
    ''' elif ask == 'mathgrade':
      st_number=input("Enter student number: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_mgrade=input("Enter the student new math grade: ")
        students[st_number]['reportCard']['grade'][0]=new_mgrade

    elif ask == 'scigrade':
      st_number=input("Enter student name: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_sgrade=input("Enter the student new science grade: ")
        #students.update({st_number:{"reportCard":{"ScienceGrade":new_sgrade}}})
        students[st_number]['reportCard']['grade'][1]=new_sgrade

    elif ask == 'ssgrade':
      st_number=input("Enter student name: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_ssgrade=input("Enter the student new social studies grade: ")
        #students.update({st_number:{"reportCard":{"Social Studies Grade":new_ssgrade}}})
        students[st_number]['reportCard']['grade'][2]=new_ssgrade

    elif ask == 'elagrade':
      st_number=input("Enter student name: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_elagrade=input("Enter the student new s E.L.A grade: ")
        #students.update({st_number:{"reportCard":{"E.L.A_grade":new_elagrade}}})
        students[st_number]['reportCard']['grade'][3]=new_elagrade'''

    if ask == 'sci_mark':
      st_number=input("Enter student number: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_sci=int(input("Enter the new mark for science: "))
        #students.update({st_number:{"reportCard":{"Science":new_sci}}})
        students[st_number]['reportCard']['Science']=new_sci
        if new_sci >= 90:
          students[st_number]['reportCard']['grade'][2]='A'
        elif new_sci >= 80 and new_sci<90:
          students[st_number]['reportCard']['grade'][2]='B'
        elif new_sci >= 70 and new_sci<80:
          students[st_number]['reportCard']['grade'][2]='C'
        elif new_sci > 60 and new_sci<70 :
          students[st_number]['reportCard']['grade'][2]='D'
        elif new_sci <= 60:
          students[st_number]['reportCard']['grade'][2]='F'
        print("Report card has been updated")


    elif ask == 'ela_mark':
      st_number=input("Enter student number: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_ela=int(input("Enter the new mark for E.L.A: "))
        #students.update({st_number:{"reportCard":{"E.L.A":new_ela}}})
        students[st_number]['reportCard']['E.L.A']=new_ela
        if new_ela >= 90:
          students[st_number]['reportCard']['grade'][1]='A'
        elif new_ela >= 80 and new_ela<90:
          students[st_number]['reportCard']['grade'][1]='B'
        elif new_ela >= 70 and new_ela<80:
          students[st_number]['reportCard']['grade'][1]='C'
        elif new_ela > 60 and new_ela<70 :
          students[st_number]['reportCard']['grade'][1]='D'
        elif new_ela <= 60:
          students[st_number]['reportCard']['grade'][1]='F'
        print("Report card has been updated")

    elif ask == 'math_mark':
      st_number=input("Enter student number: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_math=int(input("Enter the new mark for Math: "))
        #students.update({st_number:{"reportCard":{"Math":new_math}}})
        students[st_number]['reportCard']['Math']=new_math
        if new_math >= 90:
          students[st_number]['reportCard']['grade'][0]='A'
        elif new_math >= 80 and new_math<90:
          students[st_number]['reportCard']['grade'][0]='B'
        elif new_math >= 70 and new_math<80:
          students[st_number]['reportCard']['grade'][0]='C'
        elif new_math > 60 and new_math<70 :
          students[st_number]['reportCard']['grade'][0]='D'
        elif new_math <= 60:
          students[st_number]['reportCard']['grade'][0]='F'
        print("Report card has been updated")

    elif ask == 'ss_mark':
      st_number=input("Enter student number: ")
      st_name=input("Enter student name: ")
      if st_number in students and st_name==students[st_number]["name"]:
        new_ss=int(("Enter the new mark for social studies: "))
        #students.update({st_number:{"reportCard":{"Social Studies":new_ss}}})
        students[st_number]['reportCard']['Social Studies']=new_ss
        if new_ss >= 90:
          students[st_number]['reportCard']['grade'][3]='A'
        elif new_ss >= 80 and new_ss<90:
          students[st_number]['reportCard']['grade'][3]='B'
        elif new_ss >= 70 and new_ss<80:
          students[st_number]['reportCard']['grade'][3]='C'
        elif new_ss > 60 and new_ss<70 :
          students[st_number]['reportCard']['grade'][3]='D'
        elif new_ss <= 60:
          students[st_number]['reportCard']['grade'][3]='F'
        print("Report card has been updated")
    else:
      print("Invalid Input")



def calc_TotalMarks():

    st_number=input("Enter student number: ")
    st_name=input("Enter student name: ")


    if st_number in students and st_name==students[st_number]["name"]:
      math=students[st_number]["reportCard"]["Math"]
      ela=students[st_number]["reportCard"]["E.L.A"]
      sci=students[st_number]["reportCard"]["Science"]
      ss=students[st_number]["reportCard"]["Social Studies"]

      total=(math+ela+sci+ss)

      students[st_number]["reportCard"]["totalMark"]=total

      print("The total marks for",students[st_number]['name'],"is",total,"/400")

def average_Marks():

   st_number=input("Enter student number: ")
   st_name=input("Enter student name: ")

   if st_number in students and st_name==students[st_number]["name"]:
    math=students[st_number]["reportCard"]["Math"]
    ela=students[st_number]["reportCard"]["E.L.A"]
    sci=students[st_number]["reportCard"]["Science"]
    ss=students[st_number]["reportCard"]["Social Studies"]

    avg=(ela+sci+ss+math)/4

    print("Average of",students[st_number]['name'],"'s grades is:",round(avg,2))
    return
   else:
    print("Student Not In System")
    return

def percentage():


   st_number=input("Enter student number: ")
   st_name=input("Enter student name: ")

   if st_number in students and st_name==students[st_number]["name"]:

    math=students[st_number]["reportCard"]["Math"]
    ela=students[st_number]["reportCard"]["E.L.A"]
    sci=students[st_number]["reportCard"]["Science"]
    ss=students[st_number]["reportCard"]["Social Studies"]

    mathPer=math
    ssPer=ss
    elaPer=ela
    sciPer=sci

    students[st_number]["reportCard"]["Math%"]=mathPer
    students[st_number]["reportCard"]["Social Studies%"]=ssPer
    students[st_number]["reportCard"]["E.L.A%"]=elaPer
    students[st_number]["reportCard"]["Science%"]=sciPer

    print(students[st_number],"'s percentages:")
    print("Math %:",mathPer)
    print("Social Studies %:",ssPer)
    print("E.L.A %:",elaPer)
    print("Science %:",sciPer)
    return
   else:
    print("Student Not In System")
    return

def grade():
  grades=[]
  for i in students:
      print("-----------------------------")
      print( i )
      print("-----------------------------")
      if "reportCard" not in students[i]:
        print("Report Card not created for",students[i]['name'])
        print(" ")
        continue
      else:
        print("Math:",students[i]["reportCard"]['grade'][0])
        print("Science",students[i]["reportCard"]['grade'][1])
        print("E.L.A:",students[i]["reportCard"]['grade'][2])
        print("Social Studies:",students[i]["reportCard"]['grade'][3])
        print(" ")
def class_average():


  #-----Math-----
  math_seven=[]
  math_six=[]
  math_eight=[]
  for i in students:
    if students[i]['class']==6:
      math_six.append(students[i]['reportCard']['Math'])
    elif students[i]['class']==7:
      math_seven.append(students[i]['reportCard']['Math'])
    elif students[i]['class']==8:
      math_eight.append(students[i]['reportCard']['Math'])
    else:
      continue
  Mavg_seven=(sum(math_seven))/len(math_seven)
  Mavg_six=(sum(math_seven))/len(math_six)
  Mavg_eight=(sum(math_eight))/len(math_eight)
  print("-----------------------")
  print(" Class Average: Math ")
  print("-----------------------")
  print("6th grade:",round(Mavg_six,2))
  print("7th grade:",round(Mavg_seven,2))
  print("8th grade:",round(Mavg_eight,2))


  #-----E.L.A-----
  ela_seven=[]
  ela_six=[]
  ela_eight=[]
  for i in students:
    if students[i]['class']==6:
      ela_six.append(students[i]['reportCard']['E.L.A'])
    elif students[i]['class']==7:
      ela_seven.append(students[i]['reportCard']['E.L.A'])
    elif students[i]['class']==8:
      ela_eight.append(students[i]['reportCard']['E.L.A'])
    else:
      continue
  Eavg_seven=(sum(ela_seven))/len(ela_seven)
  Eavg_six=(sum(ela_seven))/len(ela_six)
  Eavg_eight=(sum(ela_eight))/len(ela_eight)
  print("-----------------------")
  print(" Class Average: E.L.A ")
  print("-----------------------")
  print("6th grade:",round(Eavg_six,2))
  print("7th grade:",round(Eavg_seven,2))
  print("8th grade:",round(Eavg_eight,2))


  #-----Science-----
  sci_seven=[]
  sci_six=[]
  sci_eight=[]
  for i in students:
    if students[i]['class']==6:
      sci_six.append(students[i]['reportCard']['Science'])
    elif students[i]['class']==7:
      sci_seven.append(students[i]['reportCard']['Science'])
    elif students[i]['class']==8:
      sci_eight.append(students[i]['reportCard']['Science'])
    else:
      continue
  Savg_seven=(sum(sci_seven))/len(sci_seven)
  Savg_six=(sum(sci_seven))/len(sci_six)
  Savg_eight=(sum(sci_eight))/len(sci_eight)
  print("-----------------------")
  print(" Class Average: Science ")
  print("-----------------------")
  print("6th grade:",round(Savg_six,2))
  print("7th grade:",round(Savg_seven,2))
  print("8th grade:",round(Savg_eight,2))


  #-----Social Studies-----
  ss_seven=[]
  ss_six=[]
  ss_eight=[]
  for i in students:
    if students[i]['class']==6:
      ss_six.append(students[i]['reportCard']['Social Studies'])
    elif students[i]['class']==7:
      math_seven.append(students[i]['reportCard']['Social Studies'])
    elif students[i]['class']==8:
      math_eight.append(students[i]['reportCard']['Social Studies'])
    else:
      continue
  SSavg_seven=(sum(ss_seven))/len(ss_seven)
  SSavg_six=(sum(ss_seven))/len(ss_six)
  SSavg_eight=(sum(ss_eight))/len(ss_eight)
  print("-----------------------")
  print(" Class Average: Social Studies ")
  print("-----------------------")
  print("6th grade:",round(SSavg_six,2))
  print("7th grade:",round(SSavg_seven,2))
  print("8th grade:",round(SSavg_eight,2))

def failed():
  print("Note: If blank, All students Passed")

  print("Failed Students: ")

  for i in students:
     f=students[i]['grade']
     if f.count('F')>=2:
      print(i)

def toppers():
  top_seven=[]
  top_six=[]
  top_eight=[]
  st_six=''
  st_seven=''
  st_eight=''
  for i in students:
    if students[i]['class']==6:
      top_six.append(students[i]['reportCard']['totalMark'])
      six=max(top_six)
      if six==students[i]['reportCard']['totalMark']:
        st_six=students[i]['name']
    elif students[i]['class']==7:
      top_seven.append(students[i]['reportCard']['totalMark'])
      seven=max(top_seven)
      if seven==students[i]['reportCard']['totalMark']:
        st_seven=students[i]['name']
    elif students[i]['class']==8:
      top_eight.append(students[i]['reportCard']['totalMark'])
      eight=max(top_eight)
      if eight==students[i]['reportCard']['totalMark']:
        st_eight=students[i]['name']
    else:
     print("Error")
     return



  print("-----------------------------")
  print("  Class Toppers  ")
  print("-----------------------------")
  print("6th grade:",st_six)
  print("7th grade:",st_seven)
  print("8th grade:",st_eight)


def attendance():
  while True:
    st_number=input("Enter student number(e.g student1,student2) or 'exit' to exit: ")
    if st_number=='exit':
          return
    for i in students:
      if i==st_number:
        p_A=input("Present or Absent('P' or 'A'): ")

        if p_A=='P' or p_A=='A':
         students[i]['attendance']=[p_A]
        else:
          print("Invalid Input")



def teacher_menu():
  while True:
    print(" ")
    print("1.Create Report Card")
    print("2.Update Report Card")
    print("3.Calculate Total Marks")
    print("4.Calculate Average Marks")
    print("5.Calculate Percentage")
    print("6.Calculate Grade")
    print("7.Calculate Class Average")
    print("8.Find Failed Students")
    print("9.Show Toppers in class")
    print("10.Attendance")
    print("11.Exit")
    print("  ")
    ask=int(input("What would you like to do: "))
    print(" ")
    if ask==1:
      create_reportCards()
    elif ask==2:
      update_reportCards()
    elif ask==3:
      calc_TotalMarks()
    elif ask==4:
      average_Marks()
    elif ask==5:
      percentage()
    elif ask==6:
      grade()
    elif ask==7:
      class_average()
    elif ask==8:
      failed()
    elif ask==9:
      toppers()
    elif ask==10:
      attendance()
    elif ask==11:
      return
    else:
      print("Invalid Input")
#teacher_menu()

# %% [markdown]
# The Teacher section should allow teachers to
# * create and update report cards for students by entering marks of different subjects.
# * Subject names can be stored in sets while marks and grades should be managed using dictionaries.
# Teachers should also be able to
# * calculate total marks,
# * average marks,
# * percentage, and
# * grade for every student.

# %%
#-----------------------------

# %% [markdown]
# The Parent section should allow parents to
# * search for their child using roll number and view the complete report card, including subjects, marks, percentage, grades, and attendance information.

# %%
#parent functions
def search():
  while True:
    roll_num=input("Enter your child's roll number: ")
    for i in students:
      if roll_num in students[i]['roll-number']:
            print("Your Child:",students[i]['name'])
            return


def view():

  roll_num=input("Enter your child's roll number: ")
  for i in students:
      if roll_num in students[i]['roll-number']:
        print("------------")
        print(" Report Card ")
        print("-------------")
        print("Math: Marks:",students[i]['reportCard']['Math'])
        print("Math: Percentage:",students[i]['reportCard']['Math%'])
        print("Math: Grade:",students[i]['reportCard']['grade'][0])
        print("E.L.A: Marks:",students[i]['reportCard']['E.L.A'])
        print("E.L.A: Percentage:",students[i]['reportCard']['E.L.A%'])
        print("E.L.A: Grade:",students[i]['reportCard']['E.L.A_grade'])
        print("Science: Marks:",students[i]['reportCard']['Science'])
        print("Science: Percentage:",students[i]['reportCard']['Science%'])
        print("Science: Grade:",students[i]['reportCard']['ScienceGrade'])
        print("Social Studies: Marks:",students[i]['reportCard']['Social Studies'],)
        print("Social Studies: Percentage:",students[i]['reportCard']['Social Studies%'])
        print("Social Studies: Grade:",students[i]['reportCard']['Social Studies Grade'])
        atten=students[i]['attendance']
        print("---------------------------")
        print(" Attendance Information ")
        print("----------------------------")
        print(students[i]['name'],"has:",atten.count('A'),"absences and has been present for", atten.count('P'),"days." )

def display_subjects():
  print("Subjects: ")
  for i in subjects:
    print("-------")
    print(i)


def parent_menu():

  while True:
    print(" ")
    print("1.Search for child")
    print("2.View")
    print("3.Display Subjects")
    print("4.Exit")
    print(" ")
    ask=int(input("Enter what you would like to do: "))
    print(" ")
    if ask==1:
      search()
    elif ask==2:
      view()
    elif ask==3:
      display_subjects()
    elif ask==4:
      return
    else:
      print("Invalid Input")
parent_menu()
# Out:
# 1.Search for child
# 2.View
# 3.Display Subjects
# 4.Exit
# Enter what you would like to do: 1
# Enter your child's roll number: 2025-601
# Your Child: Kaylee Thompson
# 1.Search for child
# 2.View
# 3.Display Subjects
# 4.Exit
# Enter what you would like to do: 2
# Enter your child's roll number: 2025-601
# 1.Search for child
# 2.View
# 3.Display Subjects
# 4.Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3459/3746881556.py in <cell line: 0>()
#      63     else:
#      64       print("Invalid Input")
# ---> 65 parent_menu()
#
# /tmp/ipykernel_3459/3746881556.py in parent_menu()
#      52     print("3.Display Subjects")
#      53     print("4.Exit")
# ---> 54     ask=int(input("Enter what you would like to do: "))
#      55     if ask==1:
#      56       search()
#
# ...

# %% [markdown]
# Lists should be used to store
# * attendance records,
# * activity logs, or
# * recent test scores.
#
# The program should include proper validations such as preventing
# * duplicate roll numbers,
# * checking whether a student exists before generating a report card, and
# * handling invalid menu choices.
#
# Additionally, the system should provide features such as
# * displaying all students,
# * showing toppers of the class,
# * finding failed students,
# * calculating class averages, and
# * displaying all unique subjects taught in the school using sets.

# %%
#main menu
def main_menu():
  try:
    while True:
      ask=input("Are you a Parent,Teacher or Admin: ").lower()
      if ask=="parent":
        parent_menu()
      elif ask=="teacher":
        teacher_menu()
      elif ask=="admin":
        admin_menu()
      else:
        print("Invalid Input")
  except IndentationError:
    print("Indentation error")
  except KeyboardInterrupt:
    print("Keyboard Interruption")
